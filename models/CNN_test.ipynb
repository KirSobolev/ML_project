# %%
import pandas as pd
import seaborn as sns
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from numpy.lib.stride_tricks import sliding_window_view
from sklearn.utils import shuffle
# %matplotlib inline
# tf crash fix
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
# Out:
# WARNING:tensorflow:From c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv("../ready_data/winter_2021.csv")

# %%
def create_target_bin(row):
    if 0.4 < row["Friction"] <= 0.6:
        return 2
    elif 0.2 < row["Friction"] <= 0.4:
        return 1
    elif row["Friction"] <= 0.2:
        return 0
    elif row["Friction"] > 0.6:
        return 3

# %%
df["friction_class"] = df.apply(create_target_bin, axis=1)

# %%
# Using MinMax scaler to scale relevant variables
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Scale only relevant variables
num_cols = ['airTemp', 'humidity', 'dewpoint', 'Friction',
       'Road_Surface_Temperature', 'Water_Film_Surface_mm']
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df["sequence"] = df.index + 1
df = df.drop("ts", axis = 1)

# %%
# Shift values of friction calss to 12 points back,
# by that we get a forecast of friction in 2 hours and can make a decision is going up or down
df['friction_class'] = df['friction_class'].shift(periods=-12)
df = df.dropna()

# %%
# To get the number of variables
n_features = len(num_cols)
n_classes = len(df["friction_class"].unique())

# %%
timestep_size = 36

input_windows = sliding_window_view(df[num_cols].values, window_shape=(timestep_size, n_features))[::timestep_size]

target_windows = sliding_window_view(df['friction_class'].values, window_shape=(timestep_size))[::timestep_size]
targets = target_windows[:,-1]

inputs = input_windows.reshape(-1,timestep_size, n_features)

X= inputs
y = targets

X,y = shuffle(X,y, random_state=42)

# %%
 # define the cutoff point
train_size = 0.8
splitter = int(len(X) * train_size)

# split to train/test
x_train = X[0:splitter]
x_test = X[splitter:]
y_train = y[0:splitter]
y_test = y[splitter:]

# %%
import keras 

def make_model(input_shape):
    model = keras.Sequential(
        [
            # input layer
            keras.layers.Input(input_shape),

            # convolutional layer 1 (we usually have 1-3 convolutional layers
            # depending how much and how complex the data is) -> "model capacity / decision space"
            keras.layers.Conv1D(filters=64, kernel_size=3, padding="same", activation="relu"),

            keras.layers.Conv1D(filters=32, kernel_size=2, padding="same", activation="relu", kernel_regularizer=keras.regularizers.L2(l2=0.1)),

            keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", activation="relu", kernel_regularizer=keras.regularizers.L1(l1=0.1)),
            # pooling + flatten (adapter from convolutional to dense)
            # flattening is done only once after the final convolutional layer 
            # and before the Dense-network
            keras.layers.GlobalAveragePooling1D(),
            keras.layers.Flatten(),

            # neural network Dense-tail
            keras.layers.Dense(16, activation="relu"),
            # output layer
            keras.layers.Dense(n_classes, activation="softmax")
        ]
    )

    return model


# make the model
model = make_model(input_shape=x_train.shape[1:])
# Out:
# WARNING:tensorflow:From c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
epochs = 1000
batch_size = 128

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "CNN.keras", save_best_only=True, monitor="sparse_categorical_accuracy"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="sparse_categorical_accuracy", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="sparse_categorical_accuracy", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# WARNING:tensorflow:From c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/1000
# WARNING:tensorflow:From c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 1s 17ms/step - loss: 15.0174 - sparse_categorical_accuracy: 0.0124 - lr: 0.0010
# Epoch 2/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 14.5099 - sparse_categorical_accuracy: 0.1224 - lr: 0.0010
# Epoch 3/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 14.0344 - sparse_categorical_accuracy: 0.4129 - lr: 0.0010
# Epoch 4/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 13.5816 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 5/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 13.1456 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 6/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 12.7223 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 7/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 12.3145 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 11.9232 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 11.5440 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 10/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 11.1766 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 11/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 10.8243 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 12/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 10.4844 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 13/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1532 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 14/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 9.8316 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 15/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5216 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 16/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 9.2207 - sparse_categorical_accuracy: 0.4336 - lr: 0.0010
# Epoch 17/1000
# 4/4 [==============================] - 0s 3ms/step - loss:
1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6107 - sparse_categorical_accuracy: 0.8195 - lr: 0.0010
# Epoch 128/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6090 - sparse_categorical_accuracy: 0.8216 - lr: 0.0010
# Epoch 129/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6019 - sparse_categorical_accuracy: 0.8257 - lr: 0.0010
# Epoch 130/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6010 - sparse_categorical_accuracy: 0.8278 - lr: 0.0010
# Epoch 131/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5957 - sparse_categorical_accuracy: 0.8299 - lr: 0.0010
# Epoch 132/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5924 - sparse_categorical_accuracy: 0.8320 - lr: 0.0010
# Epoch 133/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5915 - sparse_categorical_accuracy: 0.8257 - lr: 0.0010
# Epoch 134/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5872 - sparse_categorical_accuracy: 0.8340 - lr: 0.0010
# Epoch 135/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5871 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 136/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5824 - sparse_categorical_accuracy: 0.8299 - lr: 0.0010
# Epoch 137/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5782 - sparse_categorical_accuracy: 0.8340 - lr: 0.0010
# Epoch 138/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5762 - sparse_categorical_accuracy: 0.8340 - lr: 0.0010
# Epoch 139/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5741 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 140/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5721 - sparse_categorical_accuracy: 0.8340 - lr: 0.0010
# Epoch 141/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5699 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 142/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5686 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 143/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5676 - sparse_categorical_accuracy: 0.8382 - lr: 0.0010
# Epoch 144/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5650 - sparse_categorical_accuracy: 0.8382 - lr: 0.0010
# Epoch 145/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5633 - sparse_categorical_accuracy: 0.8382 - lr: 0.0010
# Epoch 146/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5630 - sparse_categorical_accuracy: 0.8382 - lr: 0.0010
# Epoch 147/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5606 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 148/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5598 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 149/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5612 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 150/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5562 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 151/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5563 - sparse_categorical_accuracy: 0.8382 - lr: 0.0010
# Epoch 152/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5534 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 153/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5532 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 154/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5525 - sparse_categorical_accuracy: 0.8444 - lr: 0.0010
# Epoch 155/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5517 - sparse_categorical_accuracy: 0.8382 - lr: 0.0010
# Epoch 156/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5499 - sparse_categorical_accuracy: 0.8423 - lr: 0.0010
# Epoch 157/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5486 - sparse_categorical_accuracy: 0.8423 - lr: 0.0010
# Epoch 158/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5466 - sparse_categorical_accuracy: 0.8382 - lr: 0.0010
# Epoch 159/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5464 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 160/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5506 - sparse_categorical_accuracy: 0.8423 - lr: 0.0010
# Epoch 161/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5510 - sparse_categorical_accuracy: 0.8423 - lr: 0.0010
# Epoch 162/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5428 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 163/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5485 - sparse_categorical_accuracy: 0.8444 - lr: 0.0010
# Epoch 164/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5433 - sparse_categorical_accuracy: 0.8361 - lr: 0.0010
# Epoch 165/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5436 - sparse_categorical_accuracy: 0.8444 - lr: 0.0010
# Epoch 166/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5412 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 167/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5395 - sparse_categorical_accuracy: 0.8444 - lr: 0.0010
# Epoch 168/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5389 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 169/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5380 - sparse_categorical_accuracy: 0.8444 - lr: 0.0010
# Epoch 170/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5373 - sparse_categorical_accuracy: 0.8423 - lr: 0.0010
# Epoch 171/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5356 - sparse_categorical_accuracy: 0.8423 - lr: 0.0010
# Epoch 172/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5358 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 173/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5348 - sparse_categorical_accuracy: 0.8402 - lr: 0.0010
# Epoch 174/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5353 - sparse_categorical_accuracy: 0.8444 - lr: 0.0010
# Epoch 175/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5326 - sparse_categorical_accuracy: 0.8402 - lr: 5.0000e-04
# Epoch 176/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5311 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 177/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5316 - sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 178/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5298 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 179/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5291 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 180/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5285 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 181/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5285 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 182/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5287 - sparse_categorical_accuracy: 0.8402 - lr: 5.0000e-04
# Epoch 183/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5285 - sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 184/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5274 - sparse_categorical_accuracy: 0.8465 - lr: 5.0000e-04
# Epoch 185/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5276 - sparse_categorical_accuracy: 0.8465 - lr: 5.0000e-04
# Epoch 186/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5270 - sparse_categorical_accuracy: 0.8402 - lr: 5.0000e-04
# Epoch 187/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5263 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 188/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5273 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 189/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5255 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 190/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5252 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 191/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5250 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 192/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5245 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 193/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5261 - sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 194/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5237 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 195/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5245 - sparse_categorical_accuracy: 0.8465 - lr: 5.0000e-04
# Epoch 196/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5238 - sparse_categorical_accuracy: 0.8485 - lr: 5.0000e-04
# Epoch 197/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5229 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 198/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5233 - sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 199/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5226 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 200/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5222 - sparse_categorical_accuracy: 0.8465 - lr: 5.0000e-04
# Epoch 201/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5223 - sparse_categorical_accuracy: 0.8485 - lr: 5.0000e-04
# Epoch 202/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5239 - sparse_categorical_accuracy: 0.8402 - lr: 5.0000e-04
# Epoch 203/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5218 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 204/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5218 - sparse_categorical_accuracy: 0.8485 - lr: 5.0000e-04
# Epoch 205/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5209 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 206/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5206 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 207/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5208 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 208/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5198 - sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 209/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5199 - sparse_categorical_accuracy: 0.8465 - lr: 5.0000e-04
# Epoch 210/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5201 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 211/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5193 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 212/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5195 - sparse_categorical_accuracy: 0.8423 - lr: 5.0000e-04
# Epoch 213/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5205 - sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 214/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5191 - sparse_categorical_accuracy: 0.8485 - lr: 5.0000e-04
# Epoch 215/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5188 - sparse_categorical_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 216/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5190 - sparse_categorical_accuracy: 0.8485 - lr: 5.0000e-04
# Epoch 217/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5172 - sparse_categorical_accuracy: 0.8423 - lr: 2.5000e-04
# Epoch 218/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5167 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 219/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5169 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 220/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5161 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 221/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5162 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 222/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5158 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 223/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5157 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 224/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5155 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 225/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5154 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 226/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5151 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 227/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5150 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 228/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5150 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 229/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5148 - sparse_categorical_accuracy: 0.8423 - lr: 2.5000e-04
# Epoch 230/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5147 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 231/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5147 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 232/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5145 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 233/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5146 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 234/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5143 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 235/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5140 - sparse_categorical_accuracy: 0.8444 - lr: 2.5000e-04
# Epoch 236/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5144 - sparse_categorical_accuracy: 0.8485 - lr: 2.5000e-04
# Epoch 237/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5138 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 238/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5135 - sparse_categorical_accuracy: 0.8465 - lr: 1.2500e-04
# Epoch 239/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5132 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 240/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5130 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 241/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5129 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 242/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5129 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 243/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5128 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 244/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5127 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 245/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5126 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 246/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5127 - sparse_categorical_accuracy: 0.8444 - lr: 1.2500e-04
# Epoch 246: early stopping

# %%
model = keras.models.load_model("CNN.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6853 - sparse_categorical_accuracy: 0.8347
# Test accuracy 0.8347107172012329
# Test loss 0.6852759718894958

# %%
# get predictions and convert with argmax() to get categories 
# instead of raw probabilities
test_predictions = model.predict(x_test)
test_predictions = np.argmax(test_predictions, axis=1)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y_test, test_predictions), annot=True, fmt='g')

# pretty decent, most of the cases of non-slippery
# and slippery was correctly detected
# Out:
# <Axes: >

# %%
 # print the classification report based on true values and predictions
print(classification_report(y_test, test_predictions))

# get overall accuracy of the model and print it
acc = accuracy_score(y_test, test_predictions)
print("\nModel overall accuracy: {:.2f}%".format(acc * 100))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.85      0.50      0.63        22
#          2.0       0.78      0.94      0.85        52
#          3.0       0.91      0.91      0.91        45
#
#     accuracy                           0.83       121
#    macro avg       0.63      0.59      0.60       121
# weighted avg       0.83      0.83      0.82       121
#
#
# Model overall accuracy: 83.47%
# c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\kiril\Documents\GitHub\ML_project\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
forecast_steps = 12

test_df = pd.read_csv("../ready_data/test_day.csv")
test = test_df[:-forecast_steps]
sequence = test[-37:]

input_windows = sliding_window_view(sequence[num_cols].values, window_shape=(timestep_size, n_features))[::timestep_size]
last_input = input_windows.reshape(-1,timestep_size, n_features)

# %%
future_predictions = []
for _ in range(forecast_steps):
    next_pred = model.predict(last_input)  # Predict the next time step
    # Extract the predicted class with the highest probability (using argmax)
    predicted_class = np.argmax(next_pred, axis=1)  # Get the class with the highest probability
    print("Most probable class: ", predicted_class)
    future_predictions.append(next_pred)  # Append the prediction to the list
    # Update the sequence by adding the predicted value and removing the oldest value
    last_input = np.roll(last_input, shift=-1, axis=1)
    last_input[0, -1, 0] = predicted_class[0]
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 16ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 18ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 18ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 22ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 19ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 18ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 19ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 16ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 17ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 19ms/step
# Most probable class:  [1]
# 1/1 [==============================] - 0s 46ms/step
# Most probable class:  [1]

# %%
print(future_predictions)
# Out:
# [array([[0.05092331, 0.77047175, 0.17360044, 0.0050046 ]], dtype=float32), array([[0.05092329, 0.77047145, 0.17360067, 0.00500461]], dtype=float32), array([[0.0509233 , 0.77047104, 0.17360108, 0.00500462]], dtype=float32), array([[0.05092328, 0.7704706 , 0.17360148, 0.00500463]], dtype=float32), array([[0.05092327, 0.7704701 , 0.17360194, 0.00500463]], dtype=float32), array([[0.05092326, 0.7704697 , 0.17360234, 0.00500465]], dtype=float32), array([[0.05092327, 0.77046925, 0.17360283, 0.00500466]], dtype=float32), array([[0.05092325, 0.7704689 , 0.1736032 , 0.00500467]], dtype=float32), array([[0.05092327, 0.7704684 , 0.17360365, 0.00500468]], dtype=float32), array([[0.05092326, 0.77046806, 0.17360403, 0.00500469]], dtype=float32), array([[0.05092325, 0.7704676 , 0.17360449, 0.0050047 ]], dtype=float32), array([[0.05092323, 0.7704671 , 0.17360488, 0.00500471]], dtype=float32)]
