# %%
# Usual imports
import pandas as pd
import seaborn as sns
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from phik import phik_matrix
import keras
import tensorflow as tf

# %matplotlib inline

# if your Jupyter kernel crashes during this code, use this setting
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# 

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
# Read csv file into dataframe
df = pd.read_csv("OneDrive_1_11-20-2024/winter_2022.csv")

df.head()
# Out:
#                     ts  airTemp  humidity  dewpoint  precipitation  Friction  \
# 0  2022-11-01 00:05:33      6.5     100.0       6.5              0  0.782107
# 1  2022-11-01 00:15:34      6.5     100.0       6.5              0  0.784952
# 2  2022-11-01 00:25:34      6.6     100.0       6.6              0  0.786353
# 3  2022-11-01 00:35:34      6.6     100.0       6.6              0  0.783228
# 4  2022-11-01 00:45:34      6.7     100.0       6.7              0  0.781249
#
#    Road_Surface_Temperature  Water_Film_Surface_mm
# 0                  5.254368               0.075721
# 1                  5.220150               0.069520
# 2                  5.282785               0.066547
# 3                  5.347710               0.073203
# 4                  5.426162               0.077464

# %%
# Check data statistics
df.describe()
# Out:
#             airTemp      humidity      dewpoint  precipitation      Friction  \
# count  24585.000000  24585.000000  24585.000000   24585.000000  24585.000000
# mean      -1.599549     84.943828     -4.248249       0.781574      0.653365
# std        5.520545     17.433913      5.365170       1.520350      0.160772
# min      -21.500000     18.000000    -23.600000       0.000000      0.120027
# 25%       -4.800000     81.000000     -7.700000       0.000000      0.533625
# 50%       -1.700000     91.000000     -4.000000       0.000000      0.674662
# 75%        1.500000     97.000000     -0.300000       0.000000      0.820000
# max       17.400000    100.000000     11.100000       6.000000      0.820000
#
#        Road_Surface_Temperature  Water_Film_Surface_mm
# count              24585.000000           24585.000000
# mean                  -0.406302               0.121507
# std                    5.078338               0.260198
# min                  -15.278875               0.000000
# 25%                   -3.004031               0.000000
# 50%                   -0.686799               0.061924
# 75%                    1.236727               0.125736
# max                   23.930937               5.737984

# %%
# Check dataset columns 
df.columns
# Out:
# Index(['ts', 'airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction',
#        'Road_Surface_Temperature', 'Water_Film_Surface_mm'],
#       dtype='object')

# %%
# No missing values for the merged datasets 
df.isnull().sum()
# Out:
# ts                          0
# airTemp                     0
# humidity                    0
# dewpoint                    0
# precipitation               0
# Friction                    0
# Road_Surface_Temperature    0
# Water_Film_Surface_mm       0
# dtype: int64

# %%
# Check the correleation matrix
df["sequence"] = df.index + 1
df = df.drop("ts", axis = 1)

correlation_matrix = df.corr()
target_corr = correlation_matrix["Friction"].sort_values(ascending=False)
print(target_corr)
# Out:
# Friction                    1.000000
# Road_Surface_Temperature    0.470898
# airTemp                     0.445015
# dewpoint                    0.237932
# sequence                    0.055368
# precipitation              -0.264252
# Water_Film_Surface_mm      -0.282001
# humidity                   -0.318333
# Name: Friction, dtype: float64

# %%
# Visualize the correlation
plt.figure(figsize=(8, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Using MinMax scaler to scale relevant variables
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Scale only relevant variables
num_cols = ['airTemp', 'humidity', 'dewpoint', 'Friction',
       'Road_Surface_Temperature', 'Water_Film_Surface_mm']
df[num_cols] = scaler.fit_transform(df[num_cols])

df
# Out:
#         airTemp  humidity  dewpoint  precipitation  Friction  \
# 0      0.719794  1.000000  0.867435              0  0.945865
# 1      0.719794  1.000000  0.867435              0  0.949930
# 2      0.722365  1.000000  0.870317              0  0.951931
# 3      0.722365  1.000000  0.870317              0  0.947466
# 4      0.724936  1.000000  0.873199              0  0.944639
# ...         ...       ...       ...            ...       ...
# 24580  0.619537  0.853659  0.703170              0  1.000000
# 24581  0.616967  0.841463  0.694524              0  1.000000
# 24582  0.616967  0.829268  0.691643              0  1.000000
# 24583  0.619537  0.817073  0.685879              0  1.000000
# 24584  0.624679  0.792683  0.682997              0  1.000000
#
#        Road_Surface_Temperature  Water_Film_Surface_mm  sequence
# 0                      0.523676               0.013197         1
# 1                      0.522803               0.012116         2
# 2                      0.524401               0.011598         3
# 3                      0.526057               0.012758         4
# 4                      0.528058               0.013500         5
# ...                         ...                    ...       ...
# 24580                  0.448790               0.000000     24581
# 24581                  0.448994               0.000000     24582
# 24582                  0.442979               0.000000     24583
# 24583                  0.435267               0.000000     24584
# 24584                  0.435049               0.000000     24585
#
# [24585 rows x 8 columns]

# %%
# pip install phik
import phik
import pandas as pd

# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction', 'Road_Surface_Temperature', 'Water_Film_Surface_mm', 'sequence']
#                            airTemp  humidity  dewpoint  precipitation  \
# airTemp                   1.000000  0.607187  0.927223       0.297272
# humidity                  0.607187  1.000000  0.480538       0.291359
# dewpoint                  0.927223  0.480538  1.000000       0.363384
# precipitation             0.297272  0.291359  0.363384       1.000000
# Friction                  0.585857  0.375070  0.459493       0.327031
# Road_Surface_Temperature  0.945421  0.635537  0.878962       0.332281
# Water_Film_Surface_mm     0.226370  0.122173  0.304851       0.224455
# sequence                  0.711209  0.654286  0.692581       0.268062
#
#                           Friction  Road_Surface_Temperature  \
# airTemp                   0.585857                  0.945421
# humidity                  0.375070                  0.635537
# dewpoint                  0.459493                  0.878962
# precipitation             0.327031                  0.332281
# Friction                  1.000000                  0.616073
# Road_Surface_Temperature  0.616073                  1.000000
# Water_Film_Surface_mm     0.395874                  0.302677
# sequence                  0.742519                  0.771075
#
#                           Water_Film_Surface_mm  sequence
# airTemp                                0.226370  0.711209
# humidity                               0.122173  0.654286
# dewpoint                               0.304851  0.692581
# precipitation                          0.224455  0.268062
# Friction                               0.395874  0.742519
# Road_Surface_Temperature               0.302677  0.771075
# Water_Film_Surface_mm                  1.000000  0.303026
# sequence                               0.303026  1.000000

# %%
# Compute phik-matrix values
phik_matrix = df.phik_matrix()

# Set up the plot size
plt.figure(figsize=(12, 8))

# Use seaborn's heatmap to plot the matrix
sns.heatmap(phik_matrix, annot=True, cmap="YlGnBu", vmin=0, vmax=1, cbar=True)
plt.title("Phik Correlation Matrix")
plt.show()
# Out:
# interval columns not set, guessing: ['airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction', 'Road_Surface_Temperature', 'Water_Film_Surface_mm', 'sequence']

# %%
# Check the dataframe columns 

df.columns
# Out:
# Index(['airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction',
#        'Road_Surface_Temperature', 'Water_Film_Surface_mm', 'sequence'],
#       dtype='object')

# %%
# Define function to check to cehcek when it's about to snow with the mean threshold 
def create_target_value(row):
    if row['Friction'] <= 0.5:
        return 1
    else:
        return 0
    
df['target'] = df.apply(create_target_value, axis = 1)

# %%
# Check the target values counts 
df['target'].value_counts()
# Out:
# target
# 0    20851
# 1     3734
# Name: count, dtype: int64

# %%
# Remove the last 12 target variables value to predict it with the model
df['target'] = df['target'].shift(periods=-12)

df
# Out:
#         airTemp  humidity  dewpoint  precipitation  Friction  \
# 0      0.719794  1.000000  0.867435              0  0.945865
# 1      0.719794  1.000000  0.867435              0  0.949930
# 2      0.722365  1.000000  0.870317              0  0.951931
# 3      0.722365  1.000000  0.870317              0  0.947466
# 4      0.724936  1.000000  0.873199              0  0.944639
# ...         ...       ...       ...            ...       ...
# 24580  0.619537  0.853659  0.703170              0  1.000000
# 24581  0.616967  0.841463  0.694524              0  1.000000
# 24582  0.616967  0.829268  0.691643              0  1.000000
# 24583  0.619537  0.817073  0.685879              0  1.000000
# 24584  0.624679  0.792683  0.682997              0  1.000000
#
#        Road_Surface_Temperature  Water_Film_Surface_mm  sequence  target
# 0                      0.523676               0.013197         1     0.0
# 1                      0.522803               0.012116         2     0.0
# 2                      0.524401               0.011598         3     0.0
# 3                      0.526057               0.012758         4     0.0
# 4                      0.528058               0.013500         5     0.0
# ...                         ...                    ...       ...     ...
# 24580                  0.448790               0.000000     24581     NaN
# 24581                  0.448994               0.000000     24582     NaN
# 24582                  0.442979               0.000000     24583     NaN
# 24583                  0.435267               0.000000     24584     NaN
# 24584                  0.435049               0.000000     24585     NaN
#
# [24585 rows x 9 columns]

# %%
# Plotting the whole variables in a signle graph  
df.set_index("sequence", inplace=True)

plt.figure(figsize=(12, 6))

for column in df.columns:
    plt.plot(df.index, df[column], label=column)

plt.title("All continuous variables")
plt.xlabel("Time")
plt.ylabel("Value")

plt.legend(title="Variables")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# To get the number of variables
n_features = len(num_cols)

# %%
from numpy.lib.stride_tricks import sliding_window_view

timestep_size = 50

input_windows = sliding_window_view(df[num_cols].values, window_shape=(timestep_size, n_features))[::timestep_size]

target_windows = sliding_window_view(df['target'].values, window_shape=(timestep_size))[::timestep_size]
targets = target_windows[:,-1]

inputs = input_windows.reshape(-1,timestep_size, n_features)

X= inputs
y = targets

# %%
X.shape
# Out:
# (491, 50, 6)

# %%
from sklearn.utils import shuffle

X,y = shuffle(X,y, random_state=42)

# %%
 # define the cutoff point
train_size = 0.7
splitter = int(len(X) * train_size)

# split to train/test
x_train = X[0:splitter]
x_test = X[splitter:]
y_train = y[0:splitter]
y_test = y[splitter:]

# %%
import keras 

def make_model(input_shape):
    model = keras.Sequential(
        [
            # input layer
            keras.layers.Input(input_shape),

            # convolutional layer 1 (we usually have 1-3 convolutional layers
            # depending how much and how complex the data is) -> "model capacity / decision space"
            keras.layers.Conv1D(filters=64, kernel_size=3, padding="same"),
            keras.layers.BatchNormalization(),
            keras.layers.ReLU(),

            # pooling + flatten (adapter from convolutional to dense)
            # flattening is done only once after the final convolutional layer 
            # and before the Dense-network
            keras.layers.GlobalAveragePooling1D(),
            keras.layers.Flatten(),

            # neural network Dense-tail
            keras.layers.Dense(64, activation="relu"),

            # output layer
            keras.layers.Dense(2, activation="softmax")
        ]
    )

    return model


# make the model
model = make_model(input_shape=x_train.shape[1:])

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model_classifier_22.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5808 - sparse_categorical_accuracy: 0.6761 - val_loss: 0.5128 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 2/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3156 - sparse_categorical_accuracy: 0.8643 - val_loss: 0.4527 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 3/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2856 - sparse_categorical_accuracy: 0.8707 - val_loss: 0.4261 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 4/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2293 - sparse_categorical_accuracy: 0.9194 - val_loss: 0.4158 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 5/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2124 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.4086 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 6/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2229 - sparse_categorical_accuracy: 0.8945 - val_loss: 0.4018 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 7/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2144 - sparse_categorical_accuracy: 0.9005 - val_loss: 0.3992 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 8/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2039 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.3952 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 9/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1790 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.3886 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 10/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1768 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.3795 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 11/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2464 - sparse_categorical_accuracy: 0.8848 - val_loss: 0.3730 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 12/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2111 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.3727 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 13/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2228 - sparse_categorical_accuracy: 0.8872 - val_loss: 0.3689 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 14/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2088 - sparse_categorical_accuracy: 0.8863 - val_loss: 0.3631 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 15/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1909 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.3567 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 16/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1793 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.3534 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 17/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1898 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3520 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 18/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1894 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.3479 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 19/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1819 - sparse_categorical_accuracy: 0.9109 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 20/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1760 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.3297 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 21/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2015 - sparse_categorical_accuracy: 0.9016 - val_loss: 0.3193 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 22/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1981 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3146 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 23/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2000 - sparse_categorical_accuracy: 0.9044 - val_loss: 0.3084 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 24/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1803 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.3071 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 25/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2028 - sparse_categorical_accuracy: 0.8840 - val_loss: 0.2991 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 26/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1947 - sparse_categorical_accuracy: 0.9169 - val_loss: 0.3021 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 27/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1973 - sparse_categorical_accuracy: 0.8914 - val_loss: 0.2979 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 28/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1730 - sparse_categorical_accuracy: 0.9263 - val_loss: 0.2969 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 29/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1965 - sparse_categorical_accuracy: 0.9050 - val_loss: 0.2869 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 30/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1744 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.2779 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 31/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1971 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.2922 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 32/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1683 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.2837 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 0.0010
# Epoch 33/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1824 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.2690 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 0.0010
# Epoch 34/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1714 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.2659 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 35/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1788 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.2717 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 36/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1645 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.2789 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 37/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2521 - sparse_categorical_accuracy: 0.8679 - val_loss: 0.2586 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 38/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1869 - sparse_categorical_accuracy: 0.9015 - val_loss: 0.2523 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 39/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2102 - sparse_categorical_accuracy: 0.8879 - val_loss: 0.2305 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 40/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1928 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2280 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 41/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2203 - sparse_categorical_accuracy: 0.9034 - val_loss: 0.2359 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 42/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2116 - sparse_categorical_accuracy: 0.8991 - val_loss: 0.2400 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 43/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1759 - sparse_categorical_accuracy: 0.9424 - val_loss: 0.2480 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 44/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2056 - sparse_categorical_accuracy: 0.8936 - val_loss: 0.2352 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 45/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2109 - sparse_categorical_accuracy: 0.8742 - val_loss: 0.2308 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 46/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1779 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.2326 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 47/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2074 - sparse_categorical_accuracy: 0.9092 - val_loss: 0.2258 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 0.0010
# Epoch 48/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1532 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.2163 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 49/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1540 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.2235 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 50/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1700 - sparse_categorical_accuracy: 0.9254 - val_loss: 0.2113 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 51/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2135 - sparse_categorical_accuracy: 0.8728 - val_loss: 0.2254 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 52/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1609 - sparse_categorical_accuracy: 0.9405 - val_loss: 0.2225 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 53/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1906 - sparse_categorical_accuracy: 0.9015 - val_loss: 0.2339 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 54/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1701 - sparse_categorical_accuracy: 0.9235 - val_loss: 0.2019 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 55/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2122 - sparse_categorical_accuracy: 0.9047 - val_loss: 0.2017 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 56/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1571 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.1950 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 57/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1635 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.1829 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 58/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1839 - sparse_categorical_accuracy: 0.9289 - val_loss: 0.1888 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 59/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1555 - sparse_categorical_accuracy: 0.9294 - val_loss: 0.1942 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 60/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1778 - sparse_categorical_accuracy: 0.9138 - val_loss: 0.1946 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 61/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1871 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.2056 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 62/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1518 - sparse_categorical_accuracy: 0.9148 - val_loss: 0.1901 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 63/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1866 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.1945 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 64/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1655 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.2247 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 65/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.2142 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 66/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1804 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.2065 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 67/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1851 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.2124 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 68/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1549 - sparse_categorical_accuracy: 0.9409 - val_loss: 0.2065 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 69/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.2026 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 70/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1927 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.2047 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 71/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1571 - sparse_categorical_accuracy: 0.9150 - val_loss: 0.2066 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 72/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1932 - sparse_categorical_accuracy: 0.9225 - val_loss: 0.2471 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 73/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1526 - sparse_categorical_accuracy: 0.9338 - val_loss: 0.1919 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 74/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1790 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.1973 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 75/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2174 - sparse_categorical_accuracy: 0.8812 - val_loss: 0.1776 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 76/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2107 - sparse_categorical_accuracy: 0.8942 - val_loss: 0.1926 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 77/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1737 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.2052 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 78/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1911 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.1945 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 79/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1641 - sparse_categorical_accuracy: 0.9267 - val_loss: 0.1986 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 80/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1623 - sparse_categorical_accuracy: 0.9262 - val_loss: 0.1962 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 81/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1871 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.1712 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 82/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1842 - sparse_categorical_accuracy: 0.9138 - val_loss: 0.1932 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 83/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1750 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.1951 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 84/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1405 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.1895 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 85/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1368 - sparse_categorical_accuracy: 0.9384 - val_loss: 0.1928 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 86/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.1786 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 87/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1819 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.1909 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 88/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1713 - sparse_categorical_accuracy: 0.9330 - val_loss: 0.1654 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 89/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1550 - sparse_categorical_accuracy: 0.9445 - val_loss: 0.1645 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 90/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1773 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.1673 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 91/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1532 - sparse_categorical_accuracy: 0.9387 - val_loss: 0.2005 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 92/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1395 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.1869 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 93/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1667 - sparse_categorical_accuracy: 0.9063 - val_loss: 0.1860 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 94/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1490 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.1806 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 95/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1579 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.1856 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 96/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1773 - sparse_categorical_accuracy: 0.9261 - val_loss: 0.1834 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 97/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.1879 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 98/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1411 - sparse_categorical_accuracy: 0.9267 - val_loss: 0.1733 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 99/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1298 - sparse_categorical_accuracy: 0.9454 - val_loss: 0.1838 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 100/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1548 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.2028 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 101/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1439 - sparse_categorical_accuracy: 0.9353 - val_loss: 0.1972 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 102/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1793 - sparse_categorical_accuracy: 0.9169 - val_loss: 0.1586 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 103/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1559 - sparse_categorical_accuracy: 0.9361 - val_loss: 0.1602 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 104/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1530 - sparse_categorical_accuracy: 0.9416 - val_loss: 0.1723 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 105/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2009 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.1553 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 106/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1386 - sparse_categorical_accuracy: 0.9435 - val_loss: 0.1807 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 107/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1546 - sparse_categorical_accuracy: 0.9349 - val_loss: 0.1687 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 108/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1746 - sparse_categorical_accuracy: 0.9341 - val_loss: 0.1596 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 109/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1455 - sparse_categorical_accuracy: 0.9229 - val_loss: 0.1487 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 110/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2109 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.1654 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 111/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1370 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.1706 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 112/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1541 - sparse_categorical_accuracy: 0.9383 - val_loss: 0.1969 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 113/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.2409 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 114/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1262 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.2104 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 115/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1543 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2130 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 116/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1665 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.2242 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 117/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.1791 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 118/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1677 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.1564 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 119/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9412 - val_loss: 0.1736 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 120/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1213 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1684 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 121/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1319 - sparse_categorical_accuracy: 0.9598 - val_loss: 0.1637 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 122/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1460 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.1603 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 123/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1789 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.2018 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 124/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1882 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.1807 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 125/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1466 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.1773 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 126/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1505 - sparse_categorical_accuracy: 0.9277 - val_loss: 0.1791 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 127/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1410 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.1882 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 128/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1454 - sparse_categorical_accuracy: 0.9555 - val_loss: 0.1827 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 129/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1191 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.1795 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 130/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1660 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.1625 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-04
# Epoch 131/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1583 - sparse_categorical_accuracy: 0.9387 - val_loss: 0.1615 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 132/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1337 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.1708 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 133/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1361 - sparse_categorical_accuracy: 0.9543 - val_loss: 0.1728 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 134/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1214 - sparse_categorical_accuracy: 0.9383 - val_loss: 0.1722 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 135/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1563 - sparse_categorical_accuracy: 0.9233 - val_loss: 0.1738 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 136/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1316 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.1881 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 137/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1356 - sparse_categorical_accuracy: 0.9452 - val_loss: 0.1710 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 138/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1570 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.1638 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 139/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1588 - sparse_categorical_accuracy: 0.9426 - val_loss: 0.1809 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 140/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1332 - sparse_categorical_accuracy: 0.9380 - val_loss: 0.1700 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 141/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1616 - sparse_categorical_accuracy: 0.9134 - val_loss: 0.1764 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 142/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1306 - sparse_categorical_accuracy: 0.9445 - val_loss: 0.1906 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 143/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1478 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.1959 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 144/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1433 - sparse_categorical_accuracy: 0.9487 - val_loss: 0.2049 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 145/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1309 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.1989 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 146/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1356 - sparse_categorical_accuracy: 0.9414 - val_loss: 0.2006 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 147/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1279 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.2001 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 148/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1274 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.1973 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 149/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1283 - sparse_categorical_accuracy: 0.9492 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 150/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1280 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.1933 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 151/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1237 - sparse_categorical_accuracy: 0.9526 - val_loss: 0.1933 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 152/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1546 - sparse_categorical_accuracy: 0.9548 - val_loss: 0.1911 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 153/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1491 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.1865 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 154/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1714 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.1755 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 155/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1374 - sparse_categorical_accuracy: 0.9562 - val_loss: 0.1831 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 156/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1303 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.1917 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 157/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1386 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.1916 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 158/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1250 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.1799 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 159/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1608 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.1787 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 159: early stopping

# %%
model = keras.models.load_model("best_model_classifier.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2265 - sparse_categorical_accuracy: 0.9090
# Test accuracy 0.9054054021835327
# Test loss 0.24563917517662048

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
metric = "loss"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# get predictions and convert with argmax() to get categories 
# instead of raw probabilities
test_predictions = model.predict(x_test)
test_predictions = np.argmax(test_predictions, axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y_test, test_predictions), annot=True, fmt='g')

# pretty decent, most of the cases of non-slippery
# and slippery was correctly detected
# Out:
# <Axes: >

# %%
 # print the classification report based on true values and predictions
print(classification_report(y_test, test_predictions))

# get overall accuracy of the model and print it
acc = accuracy_score(y_test, test_predictions)
print("\nModel overall accuracy: {:.2f}%".format(acc * 100))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.96      0.95       126
#          1.0       0.72      0.59      0.65        22
#
#     accuracy                           0.91       148
#    macro avg       0.83      0.78      0.80       148
# weighted avg       0.90      0.91      0.90       148
#
#
# Model overall accuracy: 90.54%

# %%
# print the ROC AUC -score
roc_auc_score(y_test, model.predict(x_test)[:, 1])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.9321789321789322

# %%
suitables = []

# loop through the y-values where it should be target == 1
amount = len(y)

for index in range(amount):
    if y[index] == 1:
        print(f"{index} - {y[index]}")
        suitables.append(index)
# Out:
# 5 - 1.0
# 7 - 1.0
# 26 - 1.0
# 30 - 1.0
# 31 - 1.0
# 32 - 1.0
# 53 - 1.0
# 54 - 1.0
# 67 - 1.0
# 68 - 1.0
# 71 - 1.0
# 76 - 1.0
# 77 - 1.0
# 79 - 1.0
# 110 - 1.0
# 116 - 1.0
# 119 - 1.0
# 122 - 1.0
# 124 - 1.0
# 133 - 1.0
# 163 - 1.0
# 184 - 1.0
# 188 - 1.0
# 190 - 1.0
# 192 - 1.0
# 197 - 1.0
# 199 - 1.0
# 206 - 1.0
# 207 - 1.0
# 234 - 1.0
# 243 - 1.0
# 248 - 1.0
# 249 - 1.0
# 260 - 1.0
# 267 - 1.0
# 274 - 1.0
# 275 - 1.0
# 276 - 1.0
# 279 - 1.0
# 288 - 1.0
# 291 - 1.0
# 298 - 1.0
# 309 - 1.0
# 312 - 1.0
# 332 - 1.0
# 335 - 1.0
# 346 - 1.0
# 351 - 1.0
# 355 - 1.0
# 366 - 1.0
# 373 - 1.0
# 386 - 1.0
# 391 - 1.0
# 393 - 1.0
# 405 - 1.0
# 406 - 1.0
# 407 - 1.0
# 408 - 1.0
# 410 - 1.0
# 430 - 1.0
# 441 - 1.0
# 458 - 1.0
# 469 - 1.0
# 470 - 1.0
# 471 - 1.0
# 474 - 1.0
# 479 - 1.0
# 490 - 1.0
