# %%
# Usual imports
import pandas as pd
import seaborn as sns
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from phik import phik_matrix
import keras
import tensorflow as tf

# %matplotlib inline

# if your Jupyter kernel crashes during this code, use this setting
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# 

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
# Read csv file into dataframe
df = pd.read_csv("OneDrive_1_11-20-2024/winter_2023.csv")

df.head()
# Out:
#                     ts  airTemp  humidity  dewpoint  precipitation  Friction  \
# 0  2022-11-01 00:05:33      6.5     100.0       6.5              0  0.782107
# 1  2022-11-01 00:15:34      6.5     100.0       6.5              0  0.784952
# 2  2022-11-01 00:25:34      6.6     100.0       6.6              0  0.786353
# 3  2022-11-01 00:35:34      6.6     100.0       6.6              0  0.783228
# 4  2022-11-01 00:45:34      6.7     100.0       6.7              0  0.781249
#
#    Road_Surface_Temperature  Water_Film_Surface_mm
# 0                  5.254368               0.075721
# 1                  5.220150               0.069520
# 2                  5.282785               0.066547
# 3                  5.347710               0.073203
# 4                  5.426162               0.077464

# %%
# Check data statistics
df.describe()
# Out:
#             airTemp      humidity      dewpoint  precipitation      Friction  \
# count  24585.000000  24585.000000  24585.000000   24585.000000  24585.000000
# mean      -1.599549     84.943828     -4.248249       0.781574      0.653365
# std        5.520545     17.433913      5.365170       1.520350      0.160772
# min      -21.500000     18.000000    -23.600000       0.000000      0.120027
# 25%       -4.800000     81.000000     -7.700000       0.000000      0.533625
# 50%       -1.700000     91.000000     -4.000000       0.000000      0.674662
# 75%        1.500000     97.000000     -0.300000       0.000000      0.820000
# max       17.400000    100.000000     11.100000       6.000000      0.820000
#
#        Road_Surface_Temperature  Water_Film_Surface_mm
# count              24585.000000           24585.000000
# mean                  -0.406302               0.121507
# std                    5.078338               0.260198
# min                  -15.278875               0.000000
# 25%                   -3.004031               0.000000
# 50%                   -0.686799               0.061924
# 75%                    1.236727               0.125736
# max                   23.930937               5.737984

# %%
# Check dataset columns 
df.columns
# Out:
# Index(['ts', 'airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction',
#        'Road_Surface_Temperature', 'Water_Film_Surface_mm'],
#       dtype='object')

# %%
# No missing values for the merged datasets 
df.isnull().sum()
# Out:
# ts                          0
# airTemp                     0
# humidity                    0
# dewpoint                    0
# precipitation               0
# Friction                    0
# Road_Surface_Temperature    0
# Water_Film_Surface_mm       0
# dtype: int64

# %%
# Check the correleation matrix
df["sequence"] = df.index + 1
df = df.drop("ts", axis = 1)

correlation_matrix = df.corr()
target_corr = correlation_matrix["Friction"].sort_values(ascending=False)
print(target_corr)
# Out:
# Friction                    1.000000
# Road_Surface_Temperature    0.470898
# airTemp                     0.445015
# dewpoint                    0.237932
# sequence                    0.055368
# precipitation              -0.264252
# Water_Film_Surface_mm      -0.282001
# humidity                   -0.318333
# Name: Friction, dtype: float64

# %%
# Visualize the correlation
plt.figure(figsize=(8, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Using MinMax scaler to scale relevant variables
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Scale only relevant variables
num_cols = ['airTemp', 'humidity', 'dewpoint', 'Friction',
       'Road_Surface_Temperature', 'Water_Film_Surface_mm']
df[num_cols] = scaler.fit_transform(df[num_cols])

df
# Out:
#         airTemp  humidity  dewpoint  precipitation  Friction  \
# 0      0.719794  1.000000  0.867435              0  0.945865
# 1      0.719794  1.000000  0.867435              0  0.949930
# 2      0.722365  1.000000  0.870317              0  0.951931
# 3      0.722365  1.000000  0.870317              0  0.947466
# 4      0.724936  1.000000  0.873199              0  0.944639
# ...         ...       ...       ...            ...       ...
# 24580  0.619537  0.853659  0.703170              0  1.000000
# 24581  0.616967  0.841463  0.694524              0  1.000000
# 24582  0.616967  0.829268  0.691643              0  1.000000
# 24583  0.619537  0.817073  0.685879              0  1.000000
# 24584  0.624679  0.792683  0.682997              0  1.000000
#
#        Road_Surface_Temperature  Water_Film_Surface_mm  sequence
# 0                      0.523676               0.013197         1
# 1                      0.522803               0.012116         2
# 2                      0.524401               0.011598         3
# 3                      0.526057               0.012758         4
# 4                      0.528058               0.013500         5
# ...                         ...                    ...       ...
# 24580                  0.448790               0.000000     24581
# 24581                  0.448994               0.000000     24582
# 24582                  0.442979               0.000000     24583
# 24583                  0.435267               0.000000     24584
# 24584                  0.435049               0.000000     24585
#
# [24585 rows x 8 columns]

# %%
# pip install phik
import phik
import pandas as pd

# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction', 'Road_Surface_Temperature', 'Water_Film_Surface_mm', 'sequence']
#                            airTemp  humidity  dewpoint  precipitation  \
# airTemp                   1.000000  0.607187  0.927223       0.297272
# humidity                  0.607187  1.000000  0.480538       0.291359
# dewpoint                  0.927223  0.480538  1.000000       0.363384
# precipitation             0.297272  0.291359  0.363384       1.000000
# Friction                  0.585857  0.375070  0.459493       0.327031
# Road_Surface_Temperature  0.945421  0.635537  0.878962       0.332281
# Water_Film_Surface_mm     0.226370  0.122173  0.304851       0.224455
# sequence                  0.711209  0.654286  0.692581       0.268062
#
#                           Friction  Road_Surface_Temperature  \
# airTemp                   0.585857                  0.945421
# humidity                  0.375070                  0.635537
# dewpoint                  0.459493                  0.878962
# precipitation             0.327031                  0.332281
# Friction                  1.000000                  0.616073
# Road_Surface_Temperature  0.616073                  1.000000
# Water_Film_Surface_mm     0.395874                  0.302677
# sequence                  0.742519                  0.771075
#
#                           Water_Film_Surface_mm  sequence
# airTemp                                0.226370  0.711209
# humidity                               0.122173  0.654286
# dewpoint                               0.304851  0.692581
# precipitation                          0.224455  0.268062
# Friction                               0.395874  0.742519
# Road_Surface_Temperature               0.302677  0.771075
# Water_Film_Surface_mm                  1.000000  0.303026
# sequence                               0.303026  1.000000

# %%
# Compute phik-matrix values
phik_matrix = df.phik_matrix()

# Set up the plot size
plt.figure(figsize=(12, 8))

# Use seaborn's heatmap to plot the matrix
sns.heatmap(phik_matrix, annot=True, cmap="YlGnBu", vmin=0, vmax=1, cbar=True)
plt.title("Phik Correlation Matrix")
plt.show()
# Out:
# interval columns not set, guessing: ['airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction', 'Road_Surface_Temperature', 'Water_Film_Surface_mm', 'sequence']

# %%
# Check the dataframe columns 

df.columns
# Out:
# Index(['airTemp', 'humidity', 'dewpoint', 'precipitation', 'Friction',
#        'Road_Surface_Temperature', 'Water_Film_Surface_mm', 'sequence'],
#       dtype='object')

# %%
# Define function to check to cehcek when it's about to snow with the mean threshold 
def create_target_value(row):
    if row['Friction'] <= 0.5:
        return 1
    else:
        return 0
    
df['target'] = df.apply(create_target_value, axis = 1)

# %%
# Check the target values counts 
df['target'].value_counts()
# Out:
# target
# 0    20851
# 1     3734
# Name: count, dtype: int64

# %%
# Remove the last 12 target variables value to predict it with the model
df['target'] = df['target'].shift(periods=-12)

df
# Out:
#         airTemp  humidity  dewpoint  precipitation  Friction  \
# 0      0.719794  1.000000  0.867435              0  0.945865
# 1      0.719794  1.000000  0.867435              0  0.949930
# 2      0.722365  1.000000  0.870317              0  0.951931
# 3      0.722365  1.000000  0.870317              0  0.947466
# 4      0.724936  1.000000  0.873199              0  0.944639
# ...         ...       ...       ...            ...       ...
# 24580  0.619537  0.853659  0.703170              0  1.000000
# 24581  0.616967  0.841463  0.694524              0  1.000000
# 24582  0.616967  0.829268  0.691643              0  1.000000
# 24583  0.619537  0.817073  0.685879              0  1.000000
# 24584  0.624679  0.792683  0.682997              0  1.000000
#
#        Road_Surface_Temperature  Water_Film_Surface_mm  sequence  target
# 0                      0.523676               0.013197         1     0.0
# 1                      0.522803               0.012116         2     0.0
# 2                      0.524401               0.011598         3     0.0
# 3                      0.526057               0.012758         4     0.0
# 4                      0.528058               0.013500         5     0.0
# ...                         ...                    ...       ...     ...
# 24580                  0.448790               0.000000     24581     NaN
# 24581                  0.448994               0.000000     24582     NaN
# 24582                  0.442979               0.000000     24583     NaN
# 24583                  0.435267               0.000000     24584     NaN
# 24584                  0.435049               0.000000     24585     NaN
#
# [24585 rows x 9 columns]

# %%
# Plotting the whole variables in a signle graph  
df.set_index("sequence", inplace=True)

plt.figure(figsize=(12, 6))

for column in df.columns:
    plt.plot(df.index, df[column], label=column)

plt.title("All continuous variables")
plt.xlabel("Time")
plt.ylabel("Value")

plt.legend(title="Variables")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# To get the number of variables
n_features = len(num_cols)

# %%
from numpy.lib.stride_tricks import sliding_window_view

timestep_size = 50

input_windows = sliding_window_view(df[num_cols].values, window_shape=(timestep_size, n_features))[::timestep_size]

target_windows = sliding_window_view(df['target'].values, window_shape=(timestep_size))[::timestep_size]
targets = target_windows[:,-1]

inputs = input_windows.reshape(-1,timestep_size, n_features)

X= inputs
y = targets

# %%
X.shape
# Out:
# (491, 50, 6)

# %%
from sklearn.utils import shuffle

X,y = shuffle(X,y, random_state=42)

# %%
 # define the cutoff point
train_size = 0.7
splitter = int(len(X) * train_size)

# split to train/test
x_train = X[0:splitter]
x_test = X[splitter:]
y_train = y[0:splitter]
y_test = y[splitter:]

# %%
import keras 

def make_model(input_shape):
    model = keras.Sequential(
        [
            # input layer
            keras.layers.Input(input_shape),

            # convolutional layer 1 (we usually have 1-3 convolutional layers
            # depending how much and how complex the data is) -> "model capacity / decision space"
            keras.layers.Conv1D(filters=64, kernel_size=3, padding="same"),
            keras.layers.BatchNormalization(),
            keras.layers.ReLU(),

            # pooling + flatten (adapter from convolutional to dense)
            # flattening is done only once after the final convolutional layer 
            # and before the Dense-network
            keras.layers.GlobalAveragePooling1D(),
            keras.layers.Flatten(),

            # neural network Dense-tail
            keras.layers.Dense(64, activation="relu"),

            # output layer
            keras.layers.Dense(2, activation="softmax")
        ]
    )

    return model


# make the model
model = make_model(input_shape=x_train.shape[1:])

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model_classifier_23.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8214 - sparse_categorical_accuracy: 0.3605 - val_loss: 0.5405 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 2/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3878 - sparse_categorical_accuracy: 0.8722 - val_loss: 0.4476 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 3/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2918 - sparse_categorical_accuracy: 0.8720 - val_loss: 0.4155 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 4/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2527 - sparse_categorical_accuracy: 0.8940 - val_loss: 0.4044 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 5/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2410 - sparse_categorical_accuracy: 0.9047 - val_loss: 0.3998 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 6/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1954 - sparse_categorical_accuracy: 0.9266 - val_loss: 0.3993 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 7/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1813 - sparse_categorical_accuracy: 0.9307 - val_loss: 0.3987 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 8/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2120 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.3921 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 9/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1954 - sparse_categorical_accuracy: 0.9223 - val_loss: 0.3877 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 10/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2612 - sparse_categorical_accuracy: 0.8734 - val_loss: 0.3814 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 11/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1965 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.3778 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 12/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2076 - sparse_categorical_accuracy: 0.8942 - val_loss: 0.3743 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 13/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1835 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.3738 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 14/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2188 - sparse_categorical_accuracy: 0.8954 - val_loss: 0.3689 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 15/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2199 - sparse_categorical_accuracy: 0.9019 - val_loss: 0.3656 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 16/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2151 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.3601 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 17/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2018 - sparse_categorical_accuracy: 0.8876 - val_loss: 0.3525 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 18/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2108 - sparse_categorical_accuracy: 0.9074 - val_loss: 0.3501 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 19/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2142 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 20/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1949 - sparse_categorical_accuracy: 0.9023 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 21/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2007 - sparse_categorical_accuracy: 0.9162 - val_loss: 0.3290 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 22/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2134 - sparse_categorical_accuracy: 0.9063 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 23/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2100 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.3232 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 24/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1973 - sparse_categorical_accuracy: 0.9138 - val_loss: 0.3261 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 25/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2327 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.3178 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 26/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1621 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.3116 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 27/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1708 - sparse_categorical_accuracy: 0.9266 - val_loss: 0.3022 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 28/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2026 - sparse_categorical_accuracy: 0.9249 - val_loss: 0.3032 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 29/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.3100 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 30/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2038 - sparse_categorical_accuracy: 0.8953 - val_loss: 0.2833 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 31/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1758 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.2797 - val_sparse_categorical_accuracy: 0.8406 - learning_rate: 0.0010
# Epoch 32/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1791 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.2668 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 33/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2087 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.2725 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 34/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1731 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.2726 - val_sparse_categorical_accuracy: 0.8551 - learning_rate: 0.0010
# Epoch 35/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1861 - sparse_categorical_accuracy: 0.9109 - val_loss: 0.2650 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 36/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1952 - sparse_categorical_accuracy: 0.9076 - val_loss: 0.2766 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 37/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1703 - sparse_categorical_accuracy: 0.9318 - val_loss: 0.2687 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 38/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1998 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.2631 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 39/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1818 - sparse_categorical_accuracy: 0.9037 - val_loss: 0.2483 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 40/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1789 - sparse_categorical_accuracy: 0.9061 - val_loss: 0.2382 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 41/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1649 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.2442 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 42/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1813 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.2372 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 43/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1986 - sparse_categorical_accuracy: 0.9249 - val_loss: 0.2362 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 44/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2027 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.2195 - val_sparse_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 45/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2004 - sparse_categorical_accuracy: 0.9029 - val_loss: 0.2208 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 46/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1935 - sparse_categorical_accuracy: 0.8975 - val_loss: 0.2204 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 47/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1549 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.2103 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 48/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1746 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.2138 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 49/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1835 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.2406 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 50/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2001 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.2114 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 51/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1642 - sparse_categorical_accuracy: 0.9237 - val_loss: 0.2026 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 52/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1688 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.2007 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 53/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1695 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.2124 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 54/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1640 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.2373 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 55/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1765 - sparse_categorical_accuracy: 0.9233 - val_loss: 0.2121 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 56/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1808 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.1977 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 57/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1821 - sparse_categorical_accuracy: 0.9099 - val_loss: 0.1979 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 58/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1780 - sparse_categorical_accuracy: 0.9145 - val_loss: 0.2094 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 59/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1321 - sparse_categorical_accuracy: 0.9420 - val_loss: 0.1764 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 60/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1696 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.1769 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 61/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1789 - sparse_categorical_accuracy: 0.9081 - val_loss: 0.1860 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 62/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1849 - sparse_categorical_accuracy: 0.9166 - val_loss: 0.1821 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 63/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9328 - val_loss: 0.1731 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 64/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1836 - sparse_categorical_accuracy: 0.9063 - val_loss: 0.1965 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 65/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1762 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.1865 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 66/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1868 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.1862 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 67/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1656 - sparse_categorical_accuracy: 0.9321 - val_loss: 0.1770 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 68/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1697 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.1744 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 69/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1359 - sparse_categorical_accuracy: 0.9452 - val_loss: 0.1810 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 70/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1737 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.1724 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 71/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1544 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.1642 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 72/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1687 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.1879 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 73/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1746 - sparse_categorical_accuracy: 0.9002 - val_loss: 0.1804 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 74/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1827 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.2078 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 75/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1719 - sparse_categorical_accuracy: 0.9203 - val_loss: 0.1768 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 76/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1856 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.1812 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 77/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1705 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.1805 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 78/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1430 - sparse_categorical_accuracy: 0.9283 - val_loss: 0.1730 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 79/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1779 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.1743 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 80/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1997 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.1661 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 81/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1631 - sparse_categorical_accuracy: 0.9216 - val_loss: 0.1712 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 82/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1817 - sparse_categorical_accuracy: 0.9042 - val_loss: 0.1801 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 83/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1378 - sparse_categorical_accuracy: 0.9540 - val_loss: 0.1753 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 84/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1390 - sparse_categorical_accuracy: 0.9518 - val_loss: 0.1723 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 85/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1764 - sparse_categorical_accuracy: 0.9289 - val_loss: 0.1849 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 86/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1318 - sparse_categorical_accuracy: 0.9561 - val_loss: 0.1614 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 87/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1620 - sparse_categorical_accuracy: 0.9296 - val_loss: 0.1680 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 88/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1439 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.1920 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 89/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.1926 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 90/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1614 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.1430 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 91/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9344 - val_loss: 0.1581 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 92/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1537 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.1517 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 93/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1668 - sparse_categorical_accuracy: 0.9242 - val_loss: 0.1592 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 94/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1293 - sparse_categorical_accuracy: 0.9363 - val_loss: 0.1640 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 95/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.1677 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 96/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1432 - sparse_categorical_accuracy: 0.9417 - val_loss: 0.1952 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 0.0010
# Epoch 97/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1402 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.1880 - val_sparse_categorical_accuracy: 0.8841 - learning_rate: 0.0010
# Epoch 98/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1579 - sparse_categorical_accuracy: 0.9381 - val_loss: 0.2026 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 0.0010
# Epoch 99/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1414 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.1833 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 100/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1866 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.1565 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 101/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9392 - val_loss: 0.1574 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 102/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1253 - sparse_categorical_accuracy: 0.9572 - val_loss: 0.1591 - val_sparse_categorical_accuracy: 0.9565 - learning_rate: 0.0010
# Epoch 103/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1228 - sparse_categorical_accuracy: 0.9541 - val_loss: 0.1676 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 104/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1394 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.1689 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 0.0010
# Epoch 105/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.1674 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 106/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9252 - val_loss: 0.1725 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 107/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1415 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.1675 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 108/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1611 - sparse_categorical_accuracy: 0.9364 - val_loss: 0.1858 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 109/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1468 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.1560 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 110/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1428 - sparse_categorical_accuracy: 0.9292 - val_loss: 0.1493 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 0.0010
# Epoch 111/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1523 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.1541 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 112/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1663 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.1665 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 113/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1499 - sparse_categorical_accuracy: 0.9491 - val_loss: 0.1672 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 114/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1315 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.1553 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 115/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1274 - sparse_categorical_accuracy: 0.9481 - val_loss: 0.1617 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 116/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1574 - sparse_categorical_accuracy: 0.9353 - val_loss: 0.1608 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 117/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1468 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.1505 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 118/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1383 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.1577 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 119/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1477 - sparse_categorical_accuracy: 0.9534 - val_loss: 0.1652 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 120/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - sparse_categorical_accuracy: 0.9468 - val_loss: 0.1592 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 121/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1501 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.1718 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 122/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1465 - sparse_categorical_accuracy: 0.9386 - val_loss: 0.1785 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 123/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1538 - sparse_categorical_accuracy: 0.9645 - val_loss: 0.1788 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 124/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1216 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1694 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-04
# Epoch 125/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1188 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.1572 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 126/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1473 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.1549 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 127/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1610 - sparse_categorical_accuracy: 0.9254 - val_loss: 0.1631 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 128/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1130 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1776 - val_sparse_categorical_accuracy: 0.9565 - learning_rate: 5.0000e-04
# Epoch 129/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1315 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.1591 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 5.0000e-04
# Epoch 130/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1514 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.1632 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 5.0000e-04
# Epoch 131/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1470 - sparse_categorical_accuracy: 0.9541 - val_loss: 0.1694 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 2.5000e-04
# Epoch 132/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1388 - sparse_categorical_accuracy: 0.9450 - val_loss: 0.1626 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 2.5000e-04
# Epoch 133/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.1690 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 2.5000e-04
# Epoch 134/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1347 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.1687 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 135/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9393 - val_loss: 0.1535 - val_sparse_categorical_accuracy: 0.9420 - learning_rate: 2.5000e-04
# Epoch 136/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1391 - sparse_categorical_accuracy: 0.9461 - val_loss: 0.1568 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 137/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1395 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.1603 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 138/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1590 - sparse_categorical_accuracy: 0.9362 - val_loss: 0.1670 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 139/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1394 - sparse_categorical_accuracy: 0.9533 - val_loss: 0.1728 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 140/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1445 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.1730 - val_sparse_categorical_accuracy: 0.9275 - learning_rate: 2.5000e-04
# Epoch 140: early stopping

# %%
model = keras.models.load_model("best_model_classifier.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2265 - sparse_categorical_accuracy: 0.9090
# Test accuracy 0.9054054021835327
# Test loss 0.24563917517662048

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
metric = "loss"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# get predictions and convert with argmax() to get categories 
# instead of raw probabilities
test_predictions = model.predict(x_test)
test_predictions = np.argmax(test_predictions, axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y_test, test_predictions), annot=True, fmt='g')

# pretty decent, most of the cases of non-slippery
# and slippery was correctly detected
# Out:
# <Axes: >

# %%
 # print the classification report based on true values and predictions
print(classification_report(y_test, test_predictions))

# get overall accuracy of the model and print it
acc = accuracy_score(y_test, test_predictions)
print("\nModel overall accuracy: {:.2f}%".format(acc * 100))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.96      0.95       126
#          1.0       0.72      0.59      0.65        22
#
#     accuracy                           0.91       148
#    macro avg       0.83      0.78      0.80       148
# weighted avg       0.90      0.91      0.90       148
#
#
# Model overall accuracy: 90.54%

# %%
# print the ROC AUC -score
roc_auc_score(y_test, model.predict(x_test)[:, 1])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0.9321789321789322

# %%
suitables = []

# loop through the y-values where it should be target == 1
amount = len(y)

for index in range(amount):
    if y[index] == 1:
        print(f"{index} - {y[index]}")
        suitables.append(index)
# Out:
# 5 - 1.0
# 7 - 1.0
# 26 - 1.0
# 30 - 1.0
# 31 - 1.0
# 32 - 1.0
# 53 - 1.0
# 54 - 1.0
# 67 - 1.0
# 68 - 1.0
# 71 - 1.0
# 76 - 1.0
# 77 - 1.0
# 79 - 1.0
# 110 - 1.0
# 116 - 1.0
# 119 - 1.0
# 122 - 1.0
# 124 - 1.0
# 133 - 1.0
# 163 - 1.0
# 184 - 1.0
# 188 - 1.0
# 190 - 1.0
# 192 - 1.0
# 197 - 1.0
# 199 - 1.0
# 206 - 1.0
# 207 - 1.0
# 234 - 1.0
# 243 - 1.0
# 248 - 1.0
# 249 - 1.0
# 260 - 1.0
# 267 - 1.0
# 274 - 1.0
# 275 - 1.0
# 276 - 1.0
# 279 - 1.0
# 288 - 1.0
# 291 - 1.0
# 298 - 1.0
# 309 - 1.0
# 312 - 1.0
# 332 - 1.0
# 335 - 1.0
# 346 - 1.0
# 351 - 1.0
# 355 - 1.0
# 366 - 1.0
# 373 - 1.0
# 386 - 1.0
# 391 - 1.0
# 393 - 1.0
# 405 - 1.0
# 406 - 1.0
# 407 - 1.0
# 408 - 1.0
# 410 - 1.0
# 430 - 1.0
# 441 - 1.0
# 458 - 1.0
# 469 - 1.0
# 470 - 1.0
# 471 - 1.0
# 474 - 1.0
# 479 - 1.0
# 490 - 1.0
